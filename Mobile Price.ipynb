# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# data = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/mobile_prices.csv")
# data.to_csv("Mobile Data.csv")

data = pd.read_csv(r"D:\PFP\Projects\Advanced Projects\Mobile Price Classification\Mobile Data.csv")
data.drop(columns=["Unnamed: 0"],inplace=True)
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
data.shape
# Out:
# (2000, 21)

# %%
data.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
plt.figure(figsize=(16,10))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm", linewidths=1)
plt.show()

# %%
x = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler

X = StandardScaler().fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.15,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

lreg = LogisticRegression()

lreg.fit(X_train,y_train)

y_predict = lreg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test,y_predict) * 100

print("Accuracy of our model is :-",acc)
# Out:
# Accuracy of our model is :- 98.33333333333333
